# %% [markdown]
# # This is a prototype of the view

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import pandas as pd
import view

# %%
x=np.array([1,2])
y=np.array([2,3])
plt.plot(x,y)
plt.scatter(x,y)

# %%
df = pd.DataFrame([[1, 1.5,2,3],[2,2,3,4],[5,4,3,2]], columns=['x', 'y','px','py'])
df1 = pd.DataFrame([[1, 1.5,2,3],[2,2,3,4],[5,4,3,2]], columns=['x', 'y','px','py'])
view.plot(df,df1)
